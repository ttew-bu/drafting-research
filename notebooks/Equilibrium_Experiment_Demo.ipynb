# %%
#import ctypes
# ctypes.cdll.LoadLibrary(r"C:\Users\trist\anaconda3\Lib\site-packages\bezier\extra-dll\extra-dllbezier-8f9b8e7c.dll")

import sys
sys.path.append("..")
import pandas as pd
import numpy as np
from Agents import *
from mtg_experimentation_utilities import *

# %% [markdown]
# ## Equilbrium Experiment Workflow Demo
# What you will find below is a rather complete list of different agents in lists, then those sets of agents being grouped by majority strategy for experimentation in lists.
# You do not need to run 20 experiments to run the workflow, but if you are running a large batch, the workflow below is representative of how you should proceed.

# %%
##Below are the lists that will be nested into the groupings per experiment (e.g. all the experiements with a majority strategy for)
##In the future, it could be good to automate these as opposed to writing out lists by hand; ran out of time to hit this optimization.
#BASELINES
basic = [
  Basic_Agent(), 
  Basic_Agent(), 
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(), 
]

fk = [
Force_K_Agent(k_forced=5),
Force_K_Agent(k_forced=5),
Force_K_Agent(k_forced=5),
Force_K_Agent(k_forced=5),
Force_K_Agent(k_forced=5),
Force_K_Agent(k_forced=5),
Force_K_Agent(k_forced=5),
Force_K_Agent(k_forced=5),
]

hard = [
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier')
]

greedy = [
  Greedy_Agent(), 
  Greedy_Agent(), 
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent()
]

medium = [
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7])
  ]

#FK OPTIONS
comps_fk_basic = [
  Force_K_Agent(k_forced=5), 
  Basic_Agent(), 
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent()
]

comps_fk_hard = [
  Force_K_Agent(k_forced=5), 
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier')
]

comps_fk_greedy = [
  Force_K_Agent(k_forced=5), 
  Greedy_Agent(), 
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent()
]

comps_fk_medium = [
  Force_K_Agent(k_forced=5), 
  Med_Agent(arch_prefs=[4,7]), 
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7])
]

###MEDIUM OPTIONS
comps_medium_basic = [
  Med_Agent(arch_prefs=[4,7]), 
  Basic_Agent(), 
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent()
]

comps_medium_fk = [
  Med_Agent(arch_prefs=[4,7]), 
  Force_K_Agent(k_forced=5), 
  Force_K_Agent(k_forced=5), 
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),  
  Force_K_Agent(k_forced=5)]

comps_medium_greedy = [
  Med_Agent(arch_prefs=[4,7]), 
  Greedy_Agent(), 
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent()]

comps_medium_hard = [
  Med_Agent(arch_prefs=[4,7]), 
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'),  
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier')
  ]

##GREEDY OPTIONS
comps_greedy_basic = [
  Greedy_Agent(), 
  Basic_Agent(), 
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent()
]

comps_greedy_fk = [
  Greedy_Agent(), 
  Force_K_Agent(k_forced=5), 
  Force_K_Agent(k_forced=5), 
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),  
  Force_K_Agent(k_forced=5)]

comps_greedy_hard = [
  Greedy_Agent(), 
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'),  
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier'), 
  Hard_Agent(bias_function='bezier')
  ]

comps_greedy_medium = [
  Greedy_Agent(), 
  Med_Agent(arch_prefs=[4,7]), 
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7])
]

##BASIC COMPS
comps_basic_hard = [
  Basic_Agent(), 
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier'),
  Hard_Agent(bias_function='bezier')
]

comps_basic_greedy = [
  Basic_Agent(), 
  Greedy_Agent(), 
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent()
]

comps_basic_medium = [
  Basic_Agent(), 
  Med_Agent(arch_prefs=[4,7]), 
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7])
]

comps_basic_fk = [
  Basic_Agent(), 
  Force_K_Agent(k_forced=5), 
  Force_K_Agent(k_forced=5), 
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),  
  Force_K_Agent(k_forced=5)]

##HARD COMPS
comps_hard_basic = [
  Hard_Agent(bias_function='bezier'),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),
  Basic_Agent(),  
  Basic_Agent(),  
  Basic_Agent()
]

comps_hard_greedy = [
  Hard_Agent(bias_function='bezier'),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),
  Greedy_Agent(),  
  Greedy_Agent(),  
  Greedy_Agent()
]

comps_hard_medium = [
  Hard_Agent(bias_function='bezier'), 
  Med_Agent(arch_prefs=[4,7]), 
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7]),
  Med_Agent(arch_prefs=[4,7])
]

comps_hard_fk = [
  Hard_Agent(bias_function='bezier'),
  Force_K_Agent(k_forced=5), 
  Force_K_Agent(k_forced=5), 
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),
  Force_K_Agent(k_forced=5),  
  Force_K_Agent(k_forced=5)
]


#Here we are simply putting the lists of agents into buckets. In the future, it could be good to 
#automate this workflow.

#Note, the naming convention is comps_deviatingstrategy_majority_strategy
medium_experiments = [comps_fk_medium,comps_basic_medium,comps_greedy_medium,comps_hard_medium]

hard_experiments = [comps_fk_hard,comps_basic_hard,comps_greedy_hard,comps_medium_hard]

basic_experiments = [comps_fk_basic,comps_hard_basic,comps_greedy_basic,comps_medium_basic]

greed_experiments = [comps_hard_greedy,comps_basic_greedy,comps_medium_greedy,comps_fk_greedy]

force_experiments = [comps_hard_fk,comps_basic_fk,comps_greedy_fk,comps_medium_fk]

#Create lists of lists to feed into the batch generator. 
deviators = [medium_experiments,hard_experiments,basic_experiments,greed_experiments,force_experiments]
baselines = [medium,hard,basic,greedy,fk]

# %%
#In addition to setting up the agents/baselines for each experiment you will need each of the following
dirpath = "C:/Users/trist/OneDrive/Desktop/drafting-research/"

#The packs to test on; note that these are ordered so you can replicate experiments on the same packs
draft_path = dirpath + 'draft_txt_files/draft_packs_1000_2022_05_30.txt'

#We need JSON representations of the cards from MTG_JSON, not CSV, for these kinds of experiments
cards_writeback = dirpath + 'json_files/VOW_Writeback.json'

#Similar to the cards, we need the weights arrays to be stored as nested dictionaries as opposed to a csv
weights_writeback = dirpath + 'json_files/weights_writeback.json'

#Finally, we need the weights df for some validation and columns along the way; this is ordered the exact same as the dataframe
weights_df_path = dirpath + 'weights_data/processed_weights/VOM_weights_seen_rates_minmax.csv'

# %%
#If you want to create new packs, feel free to do so - the file will generate in the draft_txt_files folder
#generate_simulation_packs(n_iter=1000)

#To run a batch of ALL the experiments in the cells above, run this cell (it runs each individual experiment; 
#if you ever want to just run one experiment look at the cell below)

#TIME ESTIMATE ~700 Minutes on a relatively strong laptop for 1k
simulation_batch_runner(baselines,
deviators, 
cards_writeback,
weights_writeback,
weights_df_path,
draft_path,
abs_dir_path=dirpath,
n_iter=10,
n_cards_in_pack=14,
n_rounds=3,
n_largest_for_norm=23,
rotate_option=1)

# %%
deviators[0][0]

# %%
baselines[0]

# %%
#If you want to run a single experiment, pass in one less level of nesting (this will also generate its own UUID for the batch so you can track one off experiments)
equilibrium_experiment_runner(deviators[0][0], 
baselines[0],
cards_writeback,
weights_writeback,
weights_df_path,
draft_path,
abs_dir_path=dirpath,
n_iter=10,
n_cards_in_pack=14,
rounds=3,
n_largest_for_norm=23,
rotate_option=1)
# Out:
# start2022-06-10 10:44:06.085091
# complete2022-06-10 10:44:29.560596
